# %% [markdown]
# <a href="https://colab.research.google.com/github/vconessa/Mercado-financeiro/blob/main/Projeto_01_Comparativo_A%C3%A7%C3%A3o_e_IBOV_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Projeto 1 - Ação e seus dividentos comparado com IBOV por um período determiado pelo usuário (v1)

# %%
pip install yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: yfinance in /usr/local/lib/python3.7/dist-packages (0.1.79)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.21.6)
# Requirement already satisfied: lxml>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from yfinance) (4.9.1)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.3.5)
# Requirement already satisfied: requests>=2.26 in /usr/local/lib/python3.7/dist-packages (from yfinance) (2.28.1)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.4.4)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2022.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.15.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (1.24.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.10)

# %%
# Manipulação de dados
import pandas as pd
from datetime import date, datetime

# Visualização de dados
import seaborn as sns
import matplotlib.pyplot as plt

# Dados Financeiros 
import yfinance as yf

# %% [markdown]
# **AÇÕES IBOV **
#
# ALPA4	ALPARGATAS|
# ABEV3	AMBEV S/A|
# AMER3	AMERICANAS|
# ARZZ3	AREZZO CO|
# ASAI3	ASSAI|
# AZUL4	AZUL|
# B3SA3	B3|
# BPAN4	BANCO PAN|
# BBSE3	BBSEGURIDADE|
# BRML3	BR MALLS PAR|
# BBDC3	BRADESCO|
# BBDC4	BRADESCO|
# BRAP4	BRADESPAR|
# BBAS3	BRASIL|
# BRKM5	BRASKEM|
# BRFS3	BRF SA|
# BPAC11	BTGP BANCO|
# CRFB3	CARREFOUR BR|
# CCRO3	CCR SA|
# CMIG4	CEMIG|
# CIEL3	CIELO|
# COGN3	COGNA ON|
# CPLE6	COPEL|
# CSAN3	COSAN|
# CPFE3	CPFL ENERGIA|
# CMIN3	CSNMINERACAO|
# CVCB3	CVC BRASIL|
# CYRE3	CYRELA REALT|
# DXCO3	DEXCO|
# ECOR3	ECORODOVIAS|
# ELET3	ELETROBRAS|
# ELET6	ELETROBRAS|
# EMBR3	EMBRAER|
# ENBR3	ENERGIAS BR|
# ENGI11	ENERGISA|
# ENEV3	ENEVA|
# EGIE3	ENGIE BRASIL|
# EQTL3	EQUATORIAL|
# EZTC3	EZTEC|
# FLRY3	FLEURY|
# GGBR4	GERDAU|
# GOAU4	GERDAU MET|
# GOLL4	GOL|
# NTCO3	GRUPO NATURA|
# SOMA3	GRUPO SOMA|
# HAPV3	HAPVIDA|
# HYPE3	HYPERA|
# IGTI11	IGUATEMI S.A|
# IRBR3	IRBBRASIL RE|
# ITSA4	ITAUSA|
# ITUB4	ITAUUNIBANCO|
# JBSS3	JBS|
# KLBN11	KLABIN S/A|
# RENT3	LOCALIZA|
# LWSA3	LOCAWEB|
# LREN3	LOJAS RENNER|
# MGLU3	MAGAZ LUIZA|
# MRFG3	MARFRIG|
# CASH3	MELIUZ|
# BEEF3	MINERVA|
# MRVE3	MRV|
# MULT3	MULTIPLAN|
# PCAR3	P.ACUCAR-CBD|
# PETR3	PETROBRAS|
# PETR4	PETROBRAS|
# PRIO3	PETRORIO|
# PETZ3	PETZ|
# POSI3	POSITIVO TEC|
# QUAL3	QUALICORP|
# RADL3	RAIADROGASIL|
# RAIZ4	RAIZEN|
# RDOR3	REDE D OR|
# RAIL3	RUMO S.A.|
# SBSP3	SABESP|
# SANB11	SANTANDER BR|
# SMTO3	SAO MARTINHO|
# CSNA3	SID NACIONAL|
# SLCE3	SLC AGRICOLA|
# SULA11	SUL AMERICA|
# SUZB3	SUZANO S.A.|
# TAEE11	TAESA|
# VIVT3	TELEF BRASIL|
# TIMS3	TIM|
# TOTS3	TOTVS|
# UGPA3	ULTRAPAR|
# USIM5	USIMINAS|
# VALE3	VALE|
# VIIA3	VIA|
# VBBR3	VIBRA|
# WEGE3	WEG|
# YDUQ3	YDUQS PART|
#
#
# ** PARA UTILIZAÇÃO DA BIBLIOTECA YFINANCE ADICONAR (.SA) AO FINAL DO TICKER
# EXEMPLO: VALE3.SA

# %%
ticker = str(input('Ação: '))
data_i = str(input('Data início (aaaa-mm-dd): '))
data_f = str(input('Data fim (aaaa-mm-dd):  '))
# Out:
# Ação: WEGE3.SA
# Data início (aaaa-mm-dd): 2018-01-01
# Data fim (aaaa-mm-dd):  2018-12-31

# %%
df_ibov = yf.download('^BVSP',start=data_i,end=data_f, actions=True).reset_index()
df_ibov.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                        Date     Open     High      Low    Close  Adj Close  \
# 0 2018-01-02 00:00:00-02:00  76403.0  77909.0  76403.0  77891.0    77891.0
# 1 2018-01-03 00:00:00-02:00  77889.0  78414.0  77602.0  77995.0    77995.0
# 2 2018-01-04 00:00:00-02:00  77998.0  79135.0  77998.0  78647.0    78647.0
# 3 2018-01-05 00:00:00-02:00  78644.0  79071.0  78218.0  79071.0    79071.0
# 4 2018-01-08 00:00:00-02:00  79070.0  79395.0  78631.0  79379.0    79379.0
#
#     Volume  Dividends  Stock Splits
# 0  2880300          0             0
# 1  3142200          0             0
# 2  3486100          0             0
# 3  2747100          0             0
# 4  2550800          0             0

# %%
type(df_ibov)
# Out:
# pandas.core.frame.DataFrame

# %%
df_ibov.dtypes
# Out:
# Date            datetime64[ns, America/Sao_Paulo]
# Open                                      float64
# High                                      float64
# Low                                       float64
# Close                                     float64
# Adj Close                                 float64
# Volume                                      int64
# Dividends                                   int64
# Stock Splits                                int64
# dtype: object

# %%
plt.figure(figsize=(15,8))
plt.plot(df_ibov['Adj Close'])
plt.title(('IBOV - '+(data_i)+'<>'+(data_f)), fontsize=15, loc='Center')
plt.show()

# %%
df_ticker = yf.download((ticker),start=data_i,end=data_f,actions=True).reset_index()
df_ticker
# Out:
# [*********************100%***********************]  1 of 1 completed
#                          Date      Open      High       Low     Close  \
# 0   2018-01-02 00:00:00-02:00  9.365384  9.680769  9.365384  9.623076
# 1   2018-01-03 00:00:00-02:00  9.576923  9.596153  9.457692  9.476923
# 2   2018-01-04 00:00:00-02:00  9.530769  9.584615  9.384615  9.384615
# 3   2018-01-05 00:00:00-02:00  9.469230  9.480769  9.342307  9.423076
# 4   2018-01-08 00:00:00-02:00  9.426923  9.557692  9.253846  9.500000
# ..                        ...       ...       ...       ...       ...
# 241 2018-12-20 00:00:00-02:00  8.550000  8.690000  8.510000  8.625000
# 242 2018-12-21 00:00:00-02:00  8.685000  8.745000  8.570000  8.670000
# 243 2018-12-26 00:00:00-02:00  8.545000  8.660000  8.450000  8.500000
# 244 2018-12-27 00:00:00-02:00  8.550000  8.725000  8.480000  8.565000
# 245 2018-12-28 00:00:00-02:00  8.590000  8.930000  8.555000  8.770000
#
#      Adj Close   Volume  Dividends  Stock Splits
# 0     8.982484  4812860   0.000000           0.0
# 1     8.846061  4652960   0.000000           0.0
# 2     8.759897  3317600   0.000000           0.0
# 3     8.795797  2552680   0.000000           0.0
# 4     8.867602  3346200   0.000000           0.0
# ..         ...      ...        ...           ...
# 241   8.170072  6261400   0.000000           0.0
# 242   8.212697  6919600   0.000000           0.0
# 243   8.075608  3030800   0.025706           0.0
# 244   8.137362  6220400   0.000000           0.0
# 245   8.332130  7181000   0.000000           0.0
#
# [246 rows x 9 columns]

# %%
plt.figure(figsize=(15,8))
plt.plot(df_ticker['Adj Close'])
plt.title((ticker)+' - ' +(data_i)+'<>'+(data_f), fontsize=15, loc='Center')
plt.show()

# %%
df_comparativo = pd.DataFrame((df_ibov['Adj Close'], df_ticker['Adj Close'])).T
df_comparativo.head()
# Out:
#    Adj Close  Adj Close
# 0    77891.0   8.982484
# 1    77995.0   8.846061
# 2    78647.0   8.759897
# 3    79071.0   8.795797
# 4    79379.0   8.867602

# %%
# Alterando nome das colunas
df_comparativo.columns = ['Close IBOV', ((ticker))]
df_comparativo.head()
# Out:
#    Close IBOV  WEGE3.SA
# 0     77891.0  8.982484
# 1     77995.0  8.846061
# 2     78647.0  8.759897
# 3     79071.0  8.795797
# 4     79379.0  8.867602

# %%
# Normalização usando escalonamento de recurso min-max 
df_comparativo_min_max = df_comparativo.copy()
for column in df_comparativo_min_max.columns:
  df_comparativo_min_max[column] = (df_comparativo_min_max[column] - df_comparativo_min_max[column].min()) / (df_comparativo_min_max[column].max() - df_comparativo_min_max[column].min())
df_comparativo_min_max.head()
# Out:
#    Close IBOV  WEGE3.SA
# 0    0.403699  0.806248
# 1    0.408898  0.746541
# 2    0.441490  0.708831
# 3    0.462684  0.724543
# 4    0.478080  0.755969

# %%
plt.figure(figsize=(15,8))
plt.plot(df_comparativo_min_max['Close IBOV'])
plt.plot(df_comparativo_min_max[(ticker)])
plt.title('Comparação Normalizada (Escalonamento MIN/MAX) - '+(data_i)+'<>'+(data_f))
plt.legend(['IBOV',(ticker)])
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.plot(df_ticker
         ['Adj Close'])
plt.plot(df_ticker['Dividends'])
plt.title((ticker)+' - '+(data_i)+'<>'+(data_f), fontsize=15, loc='Center')
plt.show()

# %%
dividendos = df_ticker['Dividends'].sum()

# %%
quant_div = df_ticker['Dividends']
quant_div
# Out:
# 0      0.000000
# 1      0.000000
# 2      0.000000
# 3      0.000000
# 4      0.000000
#          ...
# 241    0.000000
# 242    0.000000
# 243    0.025706
# 244    0.000000
# 245    0.000000
# Name: Dividends, Length: 246, dtype: float64

# %%
ibov_abertura = df_ibov['Adj Close'][0]
ibov_fechamento = df_ibov['Adj Close'][len(df_ibov)-1]
ibov = (((ibov_fechamento/ibov_abertura)-1)*100) 
ibov
# Out:
# 12.833318355137301

# %%
papel_abertura = df_ticker['Adj Close'][0]
papel_fechamento = df_ticker['Adj Close'][len(df_ticker)-1]
papel = (((papel_fechamento/papel_abertura)-1)*100)
papel.dtype
# Out:
# dtype('float64')

# %%
print(f'Na análise do período de {data_i} até {data_f}')
print('-'*100)
print('IBOV abriu com {} pontos e fechou com {} pontos - variação de {:.2f} % '.format(ibov_abertura,ibov_fechamento,ibov))
print('{} abriu em R${:.2f} e fechou em R${:.2f} - variação de {:.2f} % '.format(ticker,papel_abertura,papel_fechamento,papel))
print('{} somou no perído R$ {:.2f} de pagamento em dividentos por ação'.format(ticker,dividendos))
# Out:
# Na análise do período de 2018-01-01 até 2018-12-31
# ----------------------------------------------------------------------------------------------------
# IBOV abriu com 77891.0 pontos e fechou com 87887.0 pontos - variação de 12.83 %
# WEGE3.SA abriu em R$8.98 e fechou em R$8.33 - variação de -7.24 %
# WEGE3.SA somou no perído R$ 0.16 de pagamento em dividentos por ação
